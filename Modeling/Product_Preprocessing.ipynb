# %%
ls = ['DECIEM/DECIEM_Eye.csv', 'DECIEM/DECIEM_Finishers.csv',
     'DECIEM/DECIEM_Hydrators.csv', 'DECIEM/DECIEM_Masques.csv', 'DECIEM/DECIEM_Oil.csv', 'DECIEM/DECIEM_Radiance.csv',
     'DECIEM/DECIEM_Serum.csv', 'DECIEM/DECIEM_Suncare.csv']

df1 = pd.read_csv('DECIEM/DECIEM_Antioxidants.csv')

for i in ls:
    df = pd.read_csv(i)
    df1 = pd.concat([df1, df])

df1 = df1.reset_index(drop=True)

# %%
df1.tail()
# Out:
#                                   Product  \
# 128  ethylated ascorbic acid 15% solution
# 129                            survival 0
# 130                           survival 10
# 131                           survival 20
# 132                           survival 30
#
#                                            Ingredients
# 128  Propanediol, Ethyl Ascorbic Acid.\n\nOur formu...
# 129  Aqua (Water), Glycerin, Squalane, Inulin, Alga...
# 130  Cyclopentasiloxane, Aqua (Water), Zinc Oxide, ...
# 131  Cyclopentasiloxane, Aqua (Water), Zinc Oxide, ...
# 132  Cyclopentasiloxane, Aqua (Water), Zinc Oxide, ...

# %%
df2 = pd.read_csv('ing_data/Ingredients_Effect2.csv')

# %%
df2.tail()
# Out:
#                Effect                                        Ingredients
# 14       inflammation  lactic acid, glycolic acid, tartaric acid, cit...
# 15        dark_circle  arbutin, ascorbic acid, coffea arabica (coffee...
# 16          puffiness  cucumber extract, caffeine, egcg, epigallocate...
# 17            radiant          cucumber extract, lactic acid, marula oil
# 18  skin_conditioning  dimethyl isosorbide, titanium dioxide, zinc oxide

# %%
df2['Effect']
# Out:
# 0           expoliates1
# 1           expoliates2
# 2          skin_texture
# 3             skin_tone
# 4                 sebum
# 5             hydration
# 6               rosacea
# 7          pigmentation
# 8                ageing
# 9            fine_lines
# 10                 pore
# 11                 acne
# 12            blemishes
# 13             soothing
# 14         inflammation
# 15          dark_circle
# 16            puffiness
# 17              radiant
# 18    skin_conditioning
# Name: Effect, dtype: object

# %%
len(df1)
# Out:
# 133

# %%
for i in range(133):
    df1['Ingredients'][i] = df1['Ingredients'][i][:-209].lower()

# %%
df1.head()
# Out:
#                                  Product  \
# 0                           booster, c25
# 1  ethylated l-ascorbic acid 30% network
# 2   superoxide dismutase saccharide mist
# 3                             survival 0
# 4        ascorbyl glucoside solution 12%
#
#                                          Ingredients
# 0  ethoxydiglycol, ethyl ascorbic acid, hydroxyph...
# 1  ethoxydiglycol, ethyl ascorbic acid, superoxid...
# 2  aqua (water), superoxide dismutase, malachite ...
# 3  aqua (water), glycerin, squalane, inulin, alga...
# 4  aqua (water), ascorbyl glucoside, propanediol,...

# %%
all_ing = []

for i in range(60):
    ing = df1['Ingredients'][i].split(', ')
    
    for j in range(len(ing)):
        if ing[j] not in all_ing:
            all_ing.append(ing[j])
        else:
            pass

# %%
len(all_ing)
# Out:
# 368

# %%
df3 = pd.DataFrame(columns = all_ing)
df3.insert(loc=0, column='product', value=0)

# %%
df3
# Out:
# Empty DataFrame
# ...

# %%
for i in range(133):
    df3.loc[i] = 0
    df3['product'][i] = df1['Product'][i]
    ing = df1['Ingredients'][i].split(', ')
    
    for j in range(len(ing)):
        df3.loc[i][ing[j]] = 1
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df3
# Out:
#                                                product ethoxydiglycol  \
# 0                                         booster, c25              1
# 1                ethylated l-ascorbic acid 30% network              1
# 2                 superoxide dismutase saccharide mist              0
# 3                                           survival 0              1
# 4                      ascorbyl glucoside solution 12%              1
# 5    ascorbyl tetraisopalmitate solution 20% in vit...              0
# 6             vitamin c suspension 23% + ha spheres 2%              0
# 7                                 alpha lipoic acid 5%              0
# 8                 vitamin c suspension 30% in silicone              0
# 9                     resveratrol 3% + ferulic acid 3%              0
# 10                                        euk 134 0.1%              0
# 11                                           subq eyes              0
# ...

# %%
df3.to_csv('Product_p.csv', index=False)
